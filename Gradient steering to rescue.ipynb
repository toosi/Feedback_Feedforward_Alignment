# %%
runname= 'Feb16-16-54_CIFAR10_1f4065b782_729'
configpath="/home/tt2684/Research/Results/Symbio/Symbio/%s/configs.yml"%runname
# %run main_train.py   --config-file /home/tt2684/Research/Results/Symbio/Symbio/Feb16-16-54_CIFAR10_1f4065b782_729/configs.yml  --method FA
# Out:
# /share/issa/users/tt2684/Codes/Symbio/main_train.py:89: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(args.config_file)
# {   'archd': 'asymresnetT18',
#     'arche': 'asymresnet18',
#     'base_channels': 64,
#     'batch_size': 256,
#     'customdatasetdir_train': '/home/tt2684/Research/Data/Custom_datasets/CIFAR10/',
#     'databasedir': '/home/tt2684/Research/Results/database/Symbio/Easymresnet18DasymresnetT18/CIFAR10/',
#     'dataset': 'CIFAR10',
#     'dist_backend': 'nccl',
#     'dist_url': 'tcp://224.66.41.62:23456',
#     'epochs': 800,
#     'evaluate': False,
#     'factord': 0.1,
#     'factore': 0.1,
#     'gamma': 0.001,
#     'gpu': None,
#     'hash': None,
#     'imagesetdir': '/home/tt2684/Research/Data/CIFAR10/',
#     'input_size': 32,
#     'loadinitialization': '',
#     'lossfuncB': 'MSELoss',
#     'lrB': 0.0001,
# ...
